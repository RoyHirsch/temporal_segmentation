# %%
import torch

# %%
# !git clone https://github.com/ZheLi2020/TimestampActionSeg.git
# Out:
# Cloning into 'TimestampActionSeg'...
# remote: Enumerating objects: 136, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 136 (delta 12), reused 8 (delta 8), pack-reused 120
# Receiving objects: 100% (136/136), 226.95 KiB | 8.41 MiB/s, done.
# Resolving deltas: 100% (59/59), done.

# %%
# !cp /home/jupyter/TimestampActionSeg/data/50salads_annotation_all.npy /home/jupyter/data/50salads/groundTruth/
# !cp /home/jupyter/TimestampActionSeg/data/breakfast_annotation_all.npy /home/jupyter/data/breakfast/groundTruth/
# !cp /home/jupyter/TimestampActionSeg/data/gtea_annotation_all.npy /home/jupyter/data/gtea/groundTruth/

# %%
# !wget https://zenodo.org/record/3625992/files/data.zip?download=1
# Out:
# --2022-10-31 14:11:43--  https://zenodo.org/record/3625992/files/data.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.184.117.155
# Connecting to zenodo.org (zenodo.org)|188.184.117.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30210005282 (28G) [application/octet-stream]
# Saving to: ‘data.zip?download=1.1’
#
# data.zip?download=1 100%[===================>]  28.13G  7.82MB/s    in 30m 26s
#
# 2022-10-31 14:42:12 (15.8 MB/s) - ‘data.zip?download=1.1’ saved [30210005282/30210005282]

# %%
# !unzip data.zip?download=1.1
# Out:
# Archive:  data.zip?download=1.1
#    creating: data/
#    creating: data/50salads/
#    creating: data/50salads/features/
#   inflating: data/50salads/features/rgb-01-1.npy
#   inflating: data/50salads/features/rgb-01-2.npy
#   inflating: data/50salads/features/rgb-02-1.npy
#   inflating: data/50salads/features/rgb-02-2.npy
#   inflating: data/50salads/features/rgb-03-1.npy
#   inflating: data/50salads/features/rgb-03-2.npy
#   inflating: data/50salads/features/rgb-04-1.npy
#   inflating: data/50salads/features/rgb-04-2.npy
#   inflating: data/50salads/features/rgb-05-1.npy
#   inflating: data/50salads/features/rgb-05-2.npy
#   inflating: data/50salads/features/rgb-06-1.npy
#   inflating: data/50salads/features/rgb-06-2.npy
#   inflating: data/50salads/features/rgb-07-1.npy
#   inflating: data/50salads/features/rgb-07-2.npy
#   inflating: data/50salads/features/rgb-09-1.npy
#   inflating: data/50salads/features/rgb-09-2.npy
#   inflating: data/50salads/features/rgb-10-1.npy
# ...
