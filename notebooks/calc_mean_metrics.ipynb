# %%
import numpy as np
def mean(l, name):
    print('{}: {:.3f}'.format(name, np.mean(l)))

# %%
# 50salads - FB

# %%
# F1@0.10: 69.0987
# F1@0.25: 66.0944
# F1@0.50: 51.9313
# Edit: 60.1895
# Acc: 71.0865

# F1@0.10: 70.4348
# F1@0.25: 67.8261
# F1@0.50: 58.2609
# Edit: 63.0511
# Acc: 75.1602

# F1@0.10: 75.6152
# F1@0.25: 74.2729
# F1@0.50: 59.9553
# Edit: 69.7221
# Acc: 74.9462

# F1@0.10: 72.9792
# F1@0.25: 69.7460
# F1@0.50: 55.8891
# Edit: 62.9610
# Acc: 73.0634

# F1@0.10: 74.8815
# F1@0.25: 72.5118
# F1@0.50: 62.5592
# Edit: 69.3828
# Acc: 79.2254

f1_10 = [69.0987,70.4348, 75.6152,72.9792,74.8815]
f1_25 = [ 66.0944, 67.8261, 74.2729, 69.7460, 72.5118]
f1_50 = [ 51.9313, 58.2609, 59.9553, 55.8891, 62.5592]
edit = [ 69.3828, 69.7221, 63.0511, 60.1895, 62.9610]
acc = [ 79.2254, 73.0634, 74.9462, 75.1602, 71.0865]


mean(f1_10, 'F1@0.10')
mean(f1_25, 'F1@0.25')
mean(f1_50, 'F1@0.50')
mean(edit, 'Edit')
mean(acc, 'Acc')
# Out:
# F1@0.10: 72.602
# F1@0.25: 70.090
# F1@0.50: 57.719
# Edit: 65.061
# Acc: 74.696

# %%
# 50salads - RW

# %%
# F1@0.10: 66.2162
# F1@0.25: 61.2613
# F1@0.50: 45.4955
# Edit: 61.6076
# Acc: 62.0724

# F1@0.10: 69.9074
# F1@0.25: 64.8148
# F1@0.50: 48.6111
# Edit: 64.8618
# Acc: 65.6367

# F1@0.10: 70.1987
# F1@0.25: 66.2252
# F1@0.50: 49.0066
# Edit: 63.3455
# Acc: 65.9804

# F1@0.10: 59.7077
# F1@0.25: 54.6973
# F1@0.50: 44.2589
# Edit: 56.1752
# Acc: 61.2330

# F1@0.10: 72.8972
# F1@0.25: 70.0935
# F1@0.50: 50.0000
# Edit: 65.4331
# Acc: 70.0293

f1_10 = [66.2162,69.9074,72.8972,59.7077,70.1987]
f1_25 =  [61.2613,64.8148,70.0935,54.6973,66.2252]
f1_50 =  [45.4955,48.6111,50.0000,44.2589,49.0066]
edit =  [ 61.6076,64.8618,65.4331,56.1752,63.3455]
acc =  [62.0724,65.6367,70.0293,61.2330,65.9804]

mean(f1_10, 'F1@0.10')
mean(f1_25, 'F1@0.25')
mean(f1_50, 'F1@0.50')
mean(edit, 'Edit')
mean(acc, 'Acc')
# Out:
# F1@0.10: 67.785
# F1@0.25: 63.418
# F1@0.50: 47.474
# Edit: 62.285
# Acc: 64.990

# %%
# GTEA - FB

# %%
# F1@0.10: 75.3425
# F1@0.25: 69.1781
# F1@0.50: 50.6849
# Edit: 68.5715
# Acc: 63.7322

# F1@0.10: 71.9723
# F1@0.25: 69.2042
# F1@0.50: 53.9792
# Edit: 64.7512
# Acc: 69.7666

# F1@0.10: 84.4444
# F1@0.25: 79.2593
# F1@0.50: 68.8889
# Edit: 75.6714
# Acc: 70.5074

# F1@0.10: 80.7273
# F1@0.25: 79.2727
# F1@0.50: 60.3636
# Edit: 77.8791
# Acc: 70.2748

f1_10 = [80.7273,84.4444,71.9723,75.3425]
f1_25 = [79.2727,79.2593,69.2042,69.1781]
f1_50 = [60.3636,68.8889,53.9792,50.6849]
edit = [77.8791, 75.6714,64.7512,68.5715]
acc = [70.2748,70.5074, 69.7666, 63.7322]

mean(f1_10, 'F1@0.10')
mean(f1_25, 'F1@0.25')
mean(f1_50, 'F1@0.50')
mean(edit, 'Edit')
mean(acc, 'Acc')
# Out:
# F1@0.10: 78.122
# F1@0.25: 74.229
# F1@0.50: 58.479
# Edit: 71.718
# Acc: 68.570

# %%
# GTEA - RW

# %%
# F1@0.10: 76.0148
# F1@0.25: 66.4207
# F1@0.50: 45.7565
# Edit: 73.2052
# Acc: 59.9890

# F1@0.10: 68.9895
# F1@0.25: 63.4146
# F1@0.50: 48.7805
# Edit: 66.0217
# Acc: 63.0958

# F1@0.10: 78.8321
# F1@0.25: 75.9124
# F1@0.50: 58.3942
# Edit: 74.0461
# Acc: 65.8006

# F1@0.10: 79.6813
# F1@0.25: 77.2908
# F1@0.50: 55.7769
# Edit: 73.7313
# Acc: 62.1377

f1_10 = [79.6813,78.8321,68.9895,76.0148]
f1_25 = [77.2908,75.9124,63.4146,66.4207]
f1_50 = [55.7769,58.3942,48.7805,45.7565]
edit = [73.7313,74.0461,66.0217,73.2052]
acc = [62.1377,65.8006,63.0958,59.9890]

mean(f1_10, 'F1@0.10')
mean(f1_25, 'F1@0.25')
mean(f1_50, 'F1@0.50')
mean(edit, 'Edit')
mean(acc, 'Acc')
# Out:
# F1@0.10: 75.879
# F1@0.25: 70.760
# F1@0.50: 52.177
# Edit: 71.751
# Acc: 62.756
